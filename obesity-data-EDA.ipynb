# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Fly The Nest -DATA SCIENCE\Python\EDA projects\darshil-project\ObesityDataSet_raw_and_data_sinthetic.csv")

df.head(10)
# Out:
#     Age  Gender  Height  Weight        CALC FAVC  FCVC  NCP  SCC SMOKE  CH2O  \
# 0  21.0  Female    1.62    64.0          no   no   2.0  3.0   no    no   2.0
# 1  21.0  Female    1.52    56.0   Sometimes   no   3.0  3.0  yes   yes   3.0
# 2  23.0    Male    1.80    77.0  Frequently   no   2.0  3.0   no    no   2.0
# 3  27.0    Male    1.80    87.0  Frequently   no   3.0  3.0   no    no   2.0
# 4  22.0    Male    1.78    89.8   Sometimes   no   2.0  1.0   no    no   2.0
# 5  29.0    Male    1.62    53.0   Sometimes  yes   2.0  3.0   no    no   2.0
# 6  23.0  Female    1.50    55.0   Sometimes  yes   3.0  3.0   no    no   2.0
# 7  22.0    Male    1.64    53.0   Sometimes   no   2.0  3.0   no    no   2.0
# 8  24.0    Male    1.78    64.0  Frequently  yes   3.0  3.0   no    no   2.0
# 9  22.0    Male    1.72    68.0          no  yes   2.0  3.0   no    no   2.0
#
#   family_history_with_overweight  FAF  TUE       CAEC                 MTRANS  \
# ...

# %%
# CALC (Consumption of alcohol)
# FAVC (Frequent consumption of high caloric food)
# FCVC (Frequency of consumption of vegetables)
# NCP (Number of main meals)
# SCC (Calories consumption monitoring)
# CH20 (Consumption of water daily)
# FAF (Pysical activity frequency)
# TUE (Time using technology devices)
# CAEC (Consumption of food between meals)

# %%
df.shape
# Out:
# (2111, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             2111 non-null   float64
#  1   Gender                          2111 non-null   object
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   CALC                            2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   SCC                             2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  family_history_with_overweight  2111 non-null   object
# ...

# %%
df.drop(['Height','Weight','SCC', 'FCVC','NCP','CH2O','FAF','TUE'], axis=1, inplace=True)

# %%
df.head(5)
# Out:
#     Age  Gender        CALC FAVC SMOKE family_history_with_overweight  \
# 0  21.0  Female          no   no    no                            yes
# 1  21.0  Female   Sometimes   no   yes                            yes
# 2  23.0    Male  Frequently   no    no                            yes
# 3  27.0    Male  Frequently   no    no                             no
# 4  22.0    Male   Sometimes   no    no                             no
#
#         CAEC                 MTRANS           NObeyesdad
# 0  Sometimes  Public_Transportation        Normal_Weight
# 1  Sometimes  Public_Transportation        Normal_Weight
# 2  Sometimes  Public_Transportation        Normal_Weight
# 3  Sometimes                Walking   Overweight_Level_I
# 4  Sometimes  Public_Transportation  Overweight_Level_II

# %%
df.isnull().sum()
# Out:
# Age                               0
# Gender                            0
# CALC                              0
# FAVC                              0
# SMOKE                             0
# family_history_with_overweight    0
# CAEC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
df['Age']=df['Age'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             2111 non-null   int32
#  1   Gender                          2111 non-null   object
#  2   CALC                            2111 non-null   object
#  3   FAVC                            2111 non-null   object
#  4   SMOKE                           2111 non-null   object
#  5   family_history_with_overweight  2111 non-null   object
#  6   CAEC                            2111 non-null   object
#  7   MTRANS                          2111 non-null   object
#  8   NObeyesdad                      2111 non-null   object
# dtypes: int32(1), object(8)
# memory usage: 140.3+ KB

# %%
df.describe()
# Out:
#                Age
# count  2111.000000
# mean     23.972525
# std       6.308664
# min      14.000000
# 25%      19.000000
# 50%      22.000000
# 75%      26.000000
# max      61.000000

# %% [markdown]
# # Gender

# %%
gen = sns.countplot(data=df, x='Gender')

for bars in gen.containers:
    gen.bar_label(bars)

# %%
gen = sns.countplot(data=df,y='Age',hue='Gender')

for bars in gen.containers:
    gen.bar_label(bars)
    sns.set(rc={'figure.figsize':(20,15)})

# gen= sns.barplot(data=df,x='Gender', y='Age')
# sns.set(rc={'figure.figsize':(5,5)})

# %%
df.head(5)
# Out:
#    Age  Gender        CALC FAVC SMOKE family_history_with_overweight  \
# 0   21  Female          no   no    no                            yes
# 1   21  Female   Sometimes   no   yes                            yes
# 2   23    Male  Frequently   no    no                            yes
# 3   27    Male  Frequently   no    no                             no
# 4   22    Male   Sometimes   no    no                             no
#
#         CAEC                 MTRANS           NObeyesdad
# 0  Sometimes  Public_Transportation        Normal_Weight
# 1  Sometimes  Public_Transportation        Normal_Weight
# 2  Sometimes  Public_Transportation        Normal_Weight
# 3  Sometimes                Walking   Overweight_Level_I
# 4  Sometimes  Public_Transportation  Overweight_Level_II

# %% [markdown]
# # CALC (Consumption of alcohol)

# %%
df['CALC'].unique()
# Out:
# array(['no', 'Sometimes', 'Frequently', 'Always'], dtype=object)

# %%
calc = sns.countplot(data=df, x='CALC')

for bars in calc.containers:
    calc.bar_label(bars)
    sns.set(rc={'figure.figsize':(20,5)})

# %%
calc = sns.countplot(data=df, x='CALC', hue='Gender')

for bars in calc.containers:
    calc.bar_label(bars)
    sns.set(rc={'figure.figsize':(20,5)})

# %% [markdown]
# From the above graph we can see that alcohol consumption Sometimes is the highest and is done more by Female tha Male.

# %%
df.head(5)
# Out:
#    Age  Gender        CALC FAVC SMOKE family_history_with_overweight  \
# 0   21  Female          no   no    no                            yes
# 1   21  Female   Sometimes   no   yes                            yes
# 2   23    Male  Frequently   no    no                            yes
# 3   27    Male  Frequently   no    no                             no
# 4   22    Male   Sometimes   no    no                             no
#
#         CAEC                 MTRANS           NObeyesdad
# 0  Sometimes  Public_Transportation        Normal_Weight
# 1  Sometimes  Public_Transportation        Normal_Weight
# 2  Sometimes  Public_Transportation        Normal_Weight
# 3  Sometimes                Walking   Overweight_Level_I
# 4  Sometimes  Public_Transportation  Overweight_Level_II

# %% [markdown]
# # FAVC (Frequent consumption of high caloric food)

# %%
favc= sns.countplot(data=df, x='FAVC')

for bars in favc.containers:
    favc.bar_label(bars)
    sns.set(rc={'figure.figsize':(10,5)})

# %%
favc= sns.countplot(data=df, x='FAVC',hue='Gender')

for bars in favc.containers:
    favc.bar_label(bars)
    sns.set(rc={'figure.figsize':(10,5)})

# %% [markdown]
# From the above graphs we can see that the FAVC is consumed more and is majorly consumed by Male slightly more than Female

# %%
df.head(5)
# Out:
#    Age  Gender        CALC FAVC SMOKE family_history_with_overweight  \
# 0   21  Female          no   no    no                            yes
# 1   21  Female   Sometimes   no   yes                            yes
# 2   23    Male  Frequently   no    no                            yes
# 3   27    Male  Frequently   no    no                             no
# 4   22    Male   Sometimes   no    no                             no
#
#         CAEC                 MTRANS           NObeyesdad
# 0  Sometimes  Public_Transportation        Normal_Weight
# 1  Sometimes  Public_Transportation        Normal_Weight
# 2  Sometimes  Public_Transportation        Normal_Weight
# 3  Sometimes                Walking   Overweight_Level_I
# 4  Sometimes  Public_Transportation  Overweight_Level_II

# %% [markdown]
# # SMOKE

# %%
smoke= sns.countplot(data=df, x='SMOKE')

for bars in smoke.containers:
    smoke.bar_label(bars)
    sns.set(rc={'figure.figsize':(10,5)})

# %%
smoke= sns.countplot(data=df, x='SMOKE', hue='Gender')

for bars in smoke.containers:
    smoke.bar_label(bars)
    sns.set(rc={'figure.figsize':(10,5)})

# %% [markdown]
# From the above graphs we can see that the Non-SMOKERS are the highest very few SMOKERS where-in there are more Male SMOKERS than Female

# %%
df.head(5)
# Out:
#    Age  Gender        CALC FAVC SMOKE family_history_with_overweight  \
# 0   21  Female          no   no    no                            yes
# 1   21  Female   Sometimes   no   yes                            yes
# 2   23    Male  Frequently   no    no                            yes
# 3   27    Male  Frequently   no    no                             no
# 4   22    Male   Sometimes   no    no                             no
#
#         CAEC                 MTRANS           NObeyesdad
# 0  Sometimes  Public_Transportation        Normal_Weight
# 1  Sometimes  Public_Transportation        Normal_Weight
# 2  Sometimes  Public_Transportation        Normal_Weight
# 3  Sometimes                Walking   Overweight_Level_I
# 4  Sometimes  Public_Transportation  Overweight_Level_II

# %% [markdown]
# # family_history_with_overweight

# %%
fhwo = sns.countplot(data=df, x='family_history_with_overweight')

for bars in fhwo.containers:
    fhwo.bar_label(bars)
    sns.set(rc={'figure.figsize':(10,5)})

# %%
fhwo = sns.countplot(data=df, x='family_history_with_overweight', hue='Gender')

for bars in fhwo.containers:
    fhwo.bar_label(bars)
    sns.set(rc={'figure.figsize':(10,5)})

# %% [markdown]
# From the above graphs we can see that there are more people with Family_History_With_Overweight and there are more Male with the Family_History_With_Overweight than Female

# %%
df.head(5)
# Out:
#    Age  Gender        CALC FAVC SMOKE family_history_with_overweight  \
# 0   21  Female          no   no    no                            yes
# 1   21  Female   Sometimes   no   yes                            yes
# 2   23    Male  Frequently   no    no                            yes
# 3   27    Male  Frequently   no    no                             no
# 4   22    Male   Sometimes   no    no                             no
#
#         CAEC                 MTRANS           NObeyesdad
# 0  Sometimes  Public_Transportation        Normal_Weight
# 1  Sometimes  Public_Transportation        Normal_Weight
# 2  Sometimes  Public_Transportation        Normal_Weight
# 3  Sometimes                Walking   Overweight_Level_I
# 4  Sometimes  Public_Transportation  Overweight_Level_II

# %% [markdown]
# # CAEC (Consumption of food between meals)

# %%
caec=sns.countplot(data=df, x='CAEC')

for bars in caec.containers:
    caec.bar_label(bars)

# %%
caec=sns.countplot(data=df, x='CAEC',hue='Gender')

for bars in caec.containers:
    caec.bar_label(bars)

# %% [markdown]
# From the above graph we can conclude that the CAEC is done Sometimes but mostly is done by  Male

# %%
df.head(5)
# Out:
#    Age  Gender        CALC FAVC SMOKE family_history_with_overweight  \
# 0   21  Female          no   no    no                            yes
# 1   21  Female   Sometimes   no   yes                            yes
# 2   23    Male  Frequently   no    no                            yes
# 3   27    Male  Frequently   no    no                             no
# 4   22    Male   Sometimes   no    no                             no
#
#         CAEC                 MTRANS           NObeyesdad
# 0  Sometimes  Public_Transportation        Normal_Weight
# 1  Sometimes  Public_Transportation        Normal_Weight
# 2  Sometimes  Public_Transportation        Normal_Weight
# 3  Sometimes                Walking   Overweight_Level_I
# 4  Sometimes  Public_Transportation  Overweight_Level_II

# %% [markdown]
# # MTRANS

# %%
mtrans = sns.countplot(data=df, x='MTRANS')

for bars in mtrans.containers:
    mtrans.bar_label(bars)

# %%
mtrans = sns.countplot(data=df, x='MTRANS', hue='Gender')

for bars in mtrans.containers:
    mtrans.bar_label(bars)

# %% [markdown]
# From the above graphs we can see that more people uses Public_Transportaion as primary transportaion and Automobile as secondary transportation in which Female uses more of Public_Transportaion and Male uses more of Automobile transportation

# %% [markdown]
# # NObeyesdad

# %%
nob = sns.countplot(data=df, x='NObeyesdad')

for bars in nob.containers:
    nob.bar_label(bars)
    sns.set(rc={'figure.figsize':(20,5)})

# %%
nob = sns.countplot(data=df, x='NObeyesdad', hue='Gender')

for bars in nob.containers:
    nob.bar_label(bars)

# %% [markdown]
# From the above graphs we can see that the Obesity_Type_1 is the most common, but Obesity_Type_2 is more common in Male and Obesity_Type_3 is more common in Female

# %%
# keys =[]
# age_group= {'Age Group': keys}
# for i in df['Age']:
#     if i>10 and i<=20:
#         keys.append('10-20')
#     elif i>20 and i<=30:
#         keys.append('20-30')
#     elif i>30 and i<=40:
#         keys.append('30-40')
#     elif i>40 and i<=50:
#         keys.append('40-50')
#     elif i>50 and i<=60:
#         keys.append('50-60')
#     else:
#         keys.append('60+')
# print(age_group)

# df = df.append(age_group, ignore_index=True, sort=False)

# %%
df.head(10)
# Out:
#    Age  Gender        CALC FAVC SMOKE family_history_with_overweight  \
# 0   21  Female          no   no    no                            yes
# 1   21  Female   Sometimes   no   yes                            yes
# 2   23    Male  Frequently   no    no                            yes
# 3   27    Male  Frequently   no    no                             no
# 4   22    Male   Sometimes   no    no                             no
# 5   29    Male   Sometimes  yes    no                             no
# 6   23  Female   Sometimes  yes    no                            yes
# 7   22    Male   Sometimes   no    no                             no
# 8   24    Male  Frequently  yes    no                            yes
# 9   22    Male          no  yes    no                            yes
#
#         CAEC                 MTRANS           NObeyesdad
# 0  Sometimes  Public_Transportation        Normal_Weight
# 1  Sometimes  Public_Transportation        Normal_Weight
# ...

# %%
ob = sns.barplot(data=df, x='NObeyesdad', y='Age')

# %% [markdown]
# From the above graph we can see that the Obesity_Type_2, Obesity_Type_1 and Overweight_Type_2 is more common after Age 25
